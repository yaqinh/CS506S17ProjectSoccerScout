# %%
from pyvirtualdisplay import Display
from selenium import webdriver
import re
import time
import pandas as pd
import numpy as np
import os

# %%
csv = pd.read_table('FIFIndex_BPL_players.csv', sep=',', index_col = 0)
csv.head(10)
# Out:
#               Name   UpdateDate      Country  OverallScore  PotentialScore  \
# 0       Mesut Özil  Dec_12_2016      Germany            89              89
# 1       Harry Kane  Dec_12_2016      England            84              90
# 2         Coutinho  Dec_12_2016       Brazil            85              90
# 3    Sergio Agüero  Dec_12_2016    Argentina            89              89
# 4    Nemanja Matić  Dec_12_2016       Serbia            84              84
# 5  Vincent Kompany  Dec_12_2016      Belgium            85              85
# 6    Cesc Fàbregas  Dec_12_2016        Spain            86              86
# 7     Riyad Mahrez  Dec_12_2016      Algeria            84              87
# 8     Granit Xhaka  Dec_12_2016  Switzerland            84              87
# 9    Claudio Bravo  Dec_12_2016        Chile            85              85
#
#    Height Weight PreferredFoot   BirthDate  Age     ...     LongShots Curve  \
# 0  183 cm  76 kg          Left  10/15/1988   28     ...            76    84
# 1  188 cm  86 kg         Right  07/28/1993   23     ...            78    71
# 2  171 cm  68 kg         Right  06/12/1992   24     ...            85    84
# 3  172 cm  74 kg         Right  06/02/1988   28     ...            84    82
# 4  194 cm  84 kg          Left  08/01/1988   28     ...            75    68
# 5  192 cm  85 kg         Right  04/10/1986   30     ...            55    61
# 6  175 cm  74 kg         Right  05/04/1987   29     ...            75    77
# 7  179 cm  62 kg          Left  02/21/1991   25     ...            74    78
# 8  185 cm  82 kg          Left  09/27/1992   24     ...            85    68
# 9  184 cm  80 kg         Right  04/13/1983   33     ...            21    25
#
#   FKAcc Penalties Volleys  GKPositioning  GKDiving  GKHandling  GKKicking  \
# 0    79        67      77              6         6          14         10
# 1    66        82      70             14         8          10         11
# 2    79        64      75             14        12           7          9
# 3    72        80      85             11        13          15          6
# 4    67        69      74             14         7          15         12
# 5    52        63      46              8        10           9          5
# 6    81        80      81             15         6          10          8
# 7    72        72      71             11        15           9         13
# 8    70        59      50              7         7           8         11
# 9    60        23      11             78        83          85         87
#
#    GKReflexes
# 0          14
# 1          11
# 2           6
# 3          14
# 4           9
# 5           6
# 6          15
# 7           6
# 8          13
# 9          85
#
# [10 rows x 50 columns]

# %%
workRate = csv.PlayerWorkRate.tolist()
attWorkRate = []
defWorkRate = []

for item in workRate:
    lis = item.split(' / ')
    attWorkRate.append(lis[0])
    defWorkRate.append(lis[1])

csv.insert(loc=11, column='AttWorkRate', value=attWorkRate)
csv.insert(loc=12, column='DefWorkRate', value=defWorkRate) #Seperate the attack workrate and defense workrate
csv.drop('PlayerWorkRate', axis=1, inplace=True)

# %%
name = csv.Name.tolist()
birth = csv.BirthDate.tolist()
playerid = []

for ind in range(len(name)):
    playerid.append(name[ind] + ' ' + birth[ind])

csv.insert(loc=0, column='PLayerID', value=playerid) #Append name and birthdate as playerID in the csv

# %%
prePositions = csv.PreferredPositions.tolist()
counts = []
for item in prePositions:
    if '/' not in item:
        count = 1
    else:
        count = len(item.split('/'))
    
    counts.append(count)
    
csv.insert(loc=12, column='NumberofPositisions', value=counts) #Add number of positions to the csv

# %%
startYear = csv.Year.tolist()
endYear = csv.Contract.tolist()

years = []
for ind in range(len(startYear)):
    year = int(endYear[ind]) - int(startYear[ind].split('/')[2])   
    years.append(year)
    
csv.insert(loc=19, column='YearsLeftInContract', value=years) #Add years left in contract to the csv

# %%
nation = csv.Country.tolist()

homeTown = []
for item in nation:
    if item == 'England':
        homeTown.append(1)
    else:
        homeTown.append(0)
    
csv.insert(loc=4, column='IsHomeGrown', value=homeTown) #Add hownTown in contract to the csv
